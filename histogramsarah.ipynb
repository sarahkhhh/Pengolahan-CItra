# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahkhhh/Pengolahan-CItra/blob/main/histogramsarah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Sarah Khoerunisa"
nim  = 2006050

print("Nama : ",nama, "\n","Nim : ", nim)
# Out:
# Nama :  Sarah Khoerunisa
#  Nim :  2006050

# %%
from google.colab import drive
drive.mount('/foto/')
# Out:
# Mounted at /foto/

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import imageio
from google.colab.patches import cv2_imshow
img = imageio.imread('/content/drive/MyDrive/foto/IMG-20221004-WA0004.jpg')
negative=abs(255-img); 
plt.subplot(121)
plt.imshow(img);
plt.title('Original Image')
plt.axis('off') 
plt.subplot(122)
plt.imshow(negative)
plt.title('Negative Image')
plt.axis('off')
plt.show()

# %%
gray_image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=960x1280 at 0x7F89E0885450>

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 17915904
# (5184, 3456)
# uint8

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)
# Out:
# <PIL.Image.Image image mode=L size=960x1280 at 0x7F89E086EDD0>

# %%
plt.hist(img.ravel(), bins = 256, range = [0,256]);
plt.show()
